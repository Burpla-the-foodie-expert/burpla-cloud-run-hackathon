# %%
from services.conversation import ConversationManager

# %%
cm = ConversationManager()
cm.save_conversation_turn(
    session_id="session_123",
    user_id = "user_456",
    message_id = "msg_789",
    content="Hello, how are you?"
)
# Out:
# ---------------------------------------------------------------------------
# IntegrityError                            Traceback (most recent call last)
# Cell In[6], line 2
#       1 cm = ConversationManager()
# ----> 2 cm.save_conversation_turn(
#       3     session_id="session_123",
#       4     user_id = "user_456",
#       5     message_id = "msg_789",
#       6     content="Hello, how are you?"
#       7 )
#
# File ~/Desktop/cloud_hack/backend/services/conversation.py:32, in ConversationManager.save_conversation_turn(self, session_id, user_id, message_id, content)
#      30 with sqlite3.connect(self.db_path) as conn:
#      31     cursor = conn.cursor()
# ---> 32     cursor.execute("""
#      33         INSERT INTO chat_sessions (session_id, user_id, content, message_id, timestamp)
#      34         VALUES (?, ?, ?, ?, ?)
#      35     """, (session_id, user_id, content, message_id, current_time))
#
# IntegrityError: UNIQUE constraint failed: chat_sessions.session_id
